# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# # Analyzing Where Do People Drink?
#
# Estimated time needed: **30** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# -   Be confident about your data analysis skills

# %% [markdown]
# This Dataset is from the story <a href=https://fivethirtyeight.com/features/dear-mona-followup-where-do-people-drink-the-most-beer-wine-and-spirits/>  Dear Mona Followup: Where Do People Drink The Most Beer, Wine And Spirits? </a>  The dataset contains Average serving sizes per person such as average wine, spirit, beer servings. As well as several other metrics. You will be asked to analyze the data and predict the total liters served given the servings. See how to share your lab at the end.

# %% [markdown]
# You will need the following libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# <b>Importing the Data</b>

# %% [markdown]
# Load the csv:

# %%
df= pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/edx/project/drinks.csv')

# %% [markdown]
# We use the method  <code>head()</code>  to display the first 5 columns of the dataframe:

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [markdown]
# <b>Question 1</b>:  Display the data types of each column using the attribute dtype.

# %%
df.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# <b>Question 2</b> Use the method <code>groupby</code> to get the number of wine servings per continent:

# %%
df[["continent", "wine_servings"]].groupby(by = "continent", as_index=False).sum()
# Out:
#        continent  wine_servings
# 0         Africa            862
# 1           Asia            399
# 2         Europe           6400
# 3  North America            564
# 4        Oceania            570
# 5  South America            749

# %% [markdown]
# <b>Question 3:</b> Perform a statistical summary and analysis of beer servings for each continent:

# %%
continents = df["continent"].unique()
for continent in continents:
    print ("continent :" ,continent)
    print(df[df["continent"]==continent]["beer_servings"].describe().to_frame())
    print ("")
# Out:
# continent : Asia
#        beer_servings
# count      44.000000
# mean       37.045455
# std        49.469725
# min         0.000000
# 25%         4.250000
# 50%        17.500000
# 75%        60.500000
# max       247.000000
#
# continent : Europe
#        beer_servings
# count      45.000000
# mean      193.777778
# std        99.631569
# min         0.000000
# 25%       127.000000
# 50%       219.000000
# 75%       270.000000
# max       361.000000
#
# continent : Africa
#        beer_servings
# count      53.000000
# mean       61.471698
# std        80.557816
# min         0.000000
# 25%        15.000000
# 50%        32.000000
# 75%        76.000000
# max       376.000000
#
# continent : North America
#        beer_servings
# count      23.000000
# mean      145.434783
# std        79.621163
# min         1.000000
# 25%        80.000000
# 50%       143.000000
# 75%       198.000000
# max       285.000000
#
# continent : South America
#        beer_servings
# count      12.000000
# mean      175.083333
# std        65.242845
# min        93.000000
# 25%       129.500000
# 50%       162.500000
# 75%       198.000000
# max       333.000000
#
# continent : Oceania
#        beer_servings
# count      16.000000
# mean       89.687500
# std        96.641412
# min         0.000000
# 25%        21.000000
# 50%        52.500000
# 75%       125.750000
# max       306.000000

# %% [markdown]
# <b>Question 4:</b> Use the function boxplot in the seaborn library to produce a plot that can be used to show the number of beer servings on each continent.

# %%
plt.figure(figsize=(12,10))
sns.boxplot(x = "continent",y = "beer_servings", data= df )
# Out:
# <AxesSubplot:xlabel='continent', ylabel='beer_servings'>

# %% [markdown]
# <b>Question 5</b>: Use the function <code> regplot</code> in the seaborn library to determine if the number of wine servings is
# negatively or positively correlated with the number of beer servings.

# %%
plt.figure(figsize=(12,10))

sns.regplot(x = "wine_servings", y = "beer_servings", data=df)
plt.show()

# %% [markdown]
# <b> Question 6:</b> Fit a linear regression model to predict the <code>'total_litres_of_pure_alcohol'</code> using the number of <code>'wine_servings'</code> then calculate $R^{2}$:

# %%
from sklearn.linear_model import LinearRegression

x = df[["wine_servings"]]
y = df["total_litres_of_pure_alcohol"]

lm = LinearRegression()
lm.fit(x,y)
print ("R_square of model :",lm.score(x,y))
# Out:
# R_square of model : 0.4456875459787605

# %% [markdown]
# <br>
# <b>Note:</b> Please use <code>test_size = 0.10</code> and <code>random_state = 0</code> in the following questions.

# %% [markdown]
# <b>Question 7: </b>Use list of features to predict the <code>'total_litres_of_pure_alcohol'</code>, split the data into training and testing and determine the $R^2$ on the test data, using the provided code:

# %%
x = df._get_numeric_data().drop("total_litres_of_pure_alcohol", axis = 1)
y = df["total_litres_of_pure_alcohol"]

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.1, random_state = 0)

lm1 = LinearRegression()
lm1.fit(x_train, y_train)
print ("R_square of test set :", lm1.score(x_test,y_test))
# Out:
# R_square of test set : 0.6990304512837943

# %% [markdown]
# <b>Question 8 :</b> Create a pipeline object that scales the data, performs a polynomial transform and fits a linear regression model. Fit the object using the training data in the question above, then calculate the R^2 using. the test data. Take a screenshot of your code and the $R^{2}$. There are some hints in the notebook:

# %% [markdown]
# <code>'scale'</code>
#
# <code>'polynomial'</code>
#
# <code>'model'</code>
#
# The second element in the tuple contains the model constructor
#
# <code>StandardScaler()</code>
#
# <code>PolynomialFeatures(include_bias=False)</code>
#
# <code>LinearRegression()</code>

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures

scale = StandardScaler()
polynomial = PolynomialFeatures()
model = LinearRegression()

Input = [("scale",scale),("polynomial",polynomial),("model",model)]
Pipe = Pipeline(Input)

Pipe.fit(x_train, y_train)

yhat = Pipe.predict(x_test)

from sklearn.metrics import r2_score

R_square = r2_score(y_test,yhat)
print ("R_square : ", R_square)
# Out:
# R_square :  0.7076376133886035

# %% [markdown]
# <b>Question 9</b>: Create and fit a Ridge regression object using the training data, setting the regularization parameter to 0.1 and calculate the $R^{2}$ using the test data. Take a screenshot of your code and the $R^{2}$

# %%
from sklearn.linear_model import Ridge

RidgeModel = Ridge(alpha = 0.1)
RidgeModel.fit(x_train,y_train)

print ("R_Square: ",RidgeModel.score(x_test,y_test))
# Out:
# R_Square:  0.699030454901918

# %% [markdown]
# <b>Question 10 </b>: Perform a 2nd order polynomial transform on both the training data and testing data.  Create and fit a Ridge regression object using the training data, setting the regularization parameter to 0.1. Calculate the $R^{2}$ utilizing the test data provided. Take a screen-shot of your code and the $R^{2}$.

# %%
Poly = PolynomialFeatures(degree = 2)

x_train_pr = Poly.fit_transform(x_train)
x_test_pr = Poly.fit_transform(x_test)

RidgeModel = Ridge(alpha=0.1)

RidgeModel.fit(x_train_pr,y_train)

print("R_square :", RidgeModel.score(x_test_pr,y_test))
# Out:
# R_square : 0.7076376228095793

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/share-notebooks.html\" > CLICK HERE </a>  to see how to share your notebook

# %% [markdown]
# <b>Sources</b>

# %% [markdown]
# <a href=https://fivethirtyeight.com/features/dear-mona-followup-where-do-people-drink-the-most-beer-wine-and-spirits/> Dear Mona Followup: Where Do People Drink The Most Beer, Wine And Spirits?</a> by By Mona Chalabi , you can download the dataset <a href=https://github.com/fivethirtyeight/data/tree/master/alcohol-consumption>here</a>.

# %% [markdown]
# ### Thank you for completing this lab!
#
# ## Author
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/" target="_blank">Joseph Santarcangelo</a>
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                 |
# | ----------------- | ------- | ---------- | ---------------------------------- |
# | 2020-08-27        | 2.0     | Lavanya    | Moved lab to course repo in GitLab |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
